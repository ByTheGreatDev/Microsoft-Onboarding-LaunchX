# %% [markdown]
# # Microsoft Kata2 Crear un paquete

# %% [markdown]
# Crear un entorno virtual
#
# Crea un entorno virtual mediante venv

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata21.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1258x271 at 0x22C2015F970>

# %% [markdown]
# # Ejecuta el comando para activar el entorno virtual:
# source env/bin/activate
# ## Windows
# env\bin\activate
#
# o bien:
# env\Scripts\activate
#
# ## Linux, WSL or macOS
# source env/bin/activate

# %%
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata22.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=973x75 at 0x22C1EB897E0>

# %% [markdown]
# Ahora ves en tu terminal (env). Eso significa que has activado tu entorno virtual y se ha aislado del resto de tu máquina.

# %% [markdown]
# # Instalar una biblioteca
#
# Ahora que estás dentro de tu entorno virtual, puedes instalar una biblioteca y saber que la biblioteca solo existirá en el entorno virtual.
#
#     Ejecuta el comando pip freeze para ver las bibliotecas instaladas en tu entorno:

# %%
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata23.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=925x52 at 0x22C200C7EE0>

# %% [markdown]
# #### Ejecuta el comando pip install para instalar una biblioteca:

# %%
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata24.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1244x304 at 0x22C2015F910>

# %% [markdown]
# Vuelve a ejecutar pip freeze para ver cómo ha cambiado tu lista de bibliotecas:
#
# pip freeze
#
# Ahora deberías ver la siguiente lista:
#
# python-dateutil==2.8.2
# six==1.16.0

# %%
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata25.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=969x117 at 0x22C1EB8A020>

# %% [markdown]
# Desactivar un entorno virtual
#
# Hasta ahora, has creado un entorno virtual y le has agregado un paquete. Sin embargo, es posible que estés trabajando en varios proyectos de Python y necesites cambiar entre ellos. Para hacer eso, debes salir (desactivar) tu entorno virtual.
#
# Ejecuta el comando deactivate:

# %%
display.display(Image.open('C:/Users/Andy GreatDev/Desktop/kata26.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=960x121 at 0x22C1EB88A60>
